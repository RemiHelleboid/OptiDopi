# %%
import numpy as np
import matplotlib.pyplot as plt
import sys, os
import matplotlib.animation as animation
import glob, re

import scienceplots
plt.style.use('default')
plt.style.use(['science', 'high-vis', 'grid'])

# %%
def geometric_progression(x0, xmax, n, fine_part)
    x = x0
    list_x = [x0]
    while x < xmax:
        x += x * fine_part
        list_x.append(x)
        


X0 = 0
XMAX = 10
L_D = 1.1
N = 10
ALPHA = 0.5

X = geometric_progression(L_D, XMAX, N, ALPHA)

plt.plot(X, np.full_like(X, 1e11), 'o')
